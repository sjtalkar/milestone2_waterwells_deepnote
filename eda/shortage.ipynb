# %%
import sys
sys.path.append('..')

# %%
import numpy as np
import altair as alt

from lib.shortage_v2 import ShortageReportsDataset
from lib.viz import draw_missing_data_chart, get_base_map, view_year_with_slider, view_year_side_by_side, display_data_on_map, visualize_seasonality_by_month
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
shortage = ShortageReportsDataset()

# %%
print(shortage.map_df.shape)
shortage.map_df.sample(4)
# Out:
# (3771, 10)
#                        REPORT_DATE  COUNTY   LATITUDE   LONGITUDE     STATUS  \
# 505   SHORTAGE_REPORTED_2015-06-03  Madera  37.210692 -119.907219  Undefined
# 1188  SHORTAGE_REPORTED_2021-08-02  Tulare  36.428936 -119.280570  Undefined
# 2030  SHORTAGE_REPORTED_2015-10-12  Tulare  36.115734 -119.053122   Resolved
# 3757  SHORTAGE_REPORTED_2014-12-11  Madera  36.990802 -119.981320     Outage
#
#                SHORTAGE_TYPE PRIMARY_USAGES  YEAR  MONTH  \
# 505   Dry well (groundwater)      Household  2015      6
# 1188  Dry well (groundwater)      Household  2021      8
# 2030  Dry well (groundwater)      Household  2015     10
# 3757  Dry well (groundwater)      Household  2014     12
#
#                          geometry
# 505   POINT (-119.90722 37.21069)
# 1188  POINT (-119.28057 36.42894)
# 2030  POINT (-119.05312 36.11573)
# 3757  POINT (-119.98132 36.99080)

# %% [markdown]
# Pre-process the shortage report data, geospatial location and combine them into the the geospatial map_df dataset and overlay the San Joaquin Valley boundaries to keep only the data in the San Joaquin Valley

# %%
shortage.preprocess_map_df(features_to_keep= ['REPORT_DATE', 'COUNTY', 'LATITUDE', 'LONGITUDE', 'STATUS', 'SHORTAGE_TYPE', 'PRIMARY_USAGES', "YEAR", "MONTH" , "geometry"])
shortage.keep_only_sjv_data()
shortage.map_df
# Out:
#                        REPORT_DATE  COUNTY   LATITUDE   LONGITUDE     STATUS  \
# 0     SHORTAGE_REPORTED_2017-10-31    Kern  35.280117 -118.896376  Undefined
# 1     SHORTAGE_REPORTED_2018-06-01    Kern  35.290510 -118.627383  Undefined
# 2     SHORTAGE_REPORTED_2018-05-24    Kern  35.290852 -118.628775  Undefined
# 3     SHORTAGE_REPORTED_2019-05-29    Kern  35.304669 -118.914434  Undefined
# 4     SHORTAGE_REPORTED_2017-08-07    Kern  35.325274 -118.911520  Undefined
# ...                            ...     ...        ...         ...        ...
# 2524  SHORTAGE_REPORTED_2017-08-07  Merced  37.400548 -120.585828  Undefined
# 2525  SHORTAGE_REPORTED_2014-09-02  Merced  37.405558 -120.649061  Undefined
# 2526  SHORTAGE_REPORTED_2015-06-03  Merced  37.405719 -120.641678     Outage
# 2527  SHORTAGE_REPORTED_2021-09-10  Merced  37.416058 -120.661143  Undefined
# 2528  SHORTAGE_REPORTED_2015-08-31  Merced  37.425799 -120.593384  Undefined
#
#                                       SHORTAGE_TYPE PRIMARY_USAGES  YEAR  \
# 0                            Dry well (groundwater)      Household  2017
# 1                            Dry well (groundwater)      Household  2018
# 2      Owner of well will not fix problem with well      Household  2018
# 3                     smell like oil, sand in water      Household  2019
# 4                            Dry well (groundwater)      Household  2017
# ...                                             ...            ...   ...
# 2524                         Dry well (groundwater)      Household  2017
# 2525                         Dry well (groundwater)      Household  2014
# 2526                         Dry well (groundwater)      Household  2015
# 2527                         Dry well (groundwater)      Household  2021
# 2528                         Dry well (groundwater)      Household  2015
#
#       MONTH                     geometry
# 0        10  POINT (-118.89638 35.28012)
# 1         6  POINT (-118.62738 35.29051)
# 2         5  POINT (-118.62878 35.29085)
# 3         5  POINT (-118.91443 35.30467)
# 4         8  POINT (-118.91152 35.32527)
# ...     ...                          ...
# 2524      8  POINT (-120.58583 37.40055)
# 2525      9  POINT (-120.64906 37.40556)
# 2526      6  POINT (-120.64168 37.40572)
# 2527      9  POINT (-120.66114 37.41606)
# 2528      8  POINT (-120.59338 37.42580)
#
# [2529 rows x 10 columns]

# %% [markdown]
# Look at missing data in the dataset

# %%
draw_missing_data_chart(shortage.map_df)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Map of the shortages in wells in the year 2021 in the San Joaquin Valley

# %%
display_data_on_map(shortage.map_df, feature="COUNTY", year=2015)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b9e2f5d660204f418f22fd327a782494%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20table%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20margin%3A%20auto%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Next, for all Township-Ranges and every year:
#
# 1. Count the number of wells
# 2. Fill NaN values with 0

# %%
shortage.compute_features_by_township( add_well_count=True, fill_na_with_zero=False)
shortage.map_df
# Out:
#    TOWNSHIP_RANGE  YEAR                                           geometry  \
# 0       T01N R07E  2021  POLYGON ((-121.25785 37.88341, -121.25785 37.9...
# 1       T01N R08E  2021  POLYGON ((-121.14913 37.88453, -121.14913 37.9...
# 2       T01S R08E  2021  POLYGON ((-121.03392 37.88617, -121.03392 37.7...
# 3       T01S R09E  2021  POLYGON ((-121.03686 37.88683, -120.92335 37.8...
# 4       T02N R06E  2021  POLYGON ((-121.37076 37.97036, -121.37076 38.0...
# ..            ...   ...                                                ...
# 14      T23S R28E  2019  POLYGON ((-119.00029 35.87699, -119.00029 35.9...
# 15      T25S R26E  2019  POLYGON ((-119.22324 35.70335, -119.22324 35.7...
# 16      T29S R26E  2019  POLYGON ((-119.23435 35.35432, -119.23435 35.4...
# 17      T30S R28E  2019  POLYGON ((-119.02127 35.26682, -119.02127 35.3...
# 0       T11S R17E  2012  POLYGON ((-120.16626 36.92391, -120.16626 37.0...
#
#     WELL_COUNT
# 0            1
# 1            1
# 2            4
# 3            3
# 4            1
# ..         ...
# 14           1
# 15           1
# 16           1
# 17           1
# 0            1
#
# [456 rows x 4 columns]

# %%
shortage.fill_townships_with_no_data(features_to_fill=["WELL_COUNT"], feature_value=0)
shortage.map_df
# Out:
#     TOWNSHIP_RANGE  YEAR                                           geometry  \
# 0        T01N R07E  2021  POLYGON ((-121.25785 37.88341, -121.25785 37.9...
# 1        T01N R08E  2021  POLYGON ((-121.14913 37.88453, -121.14913 37.9...
# 2        T01S R08E  2021  POLYGON ((-121.03392 37.88617, -121.03392 37.7...
# 3        T01S R09E  2021  POLYGON ((-121.03686 37.88683, -120.92335 37.8...
# 4        T02N R06E  2021  POLYGON ((-121.37076 37.97036, -121.37076 38.0...
# ..             ...   ...                                                ...
# 473      T32S R26E  2012  POLYGON ((-119.23510 35.09371, -119.23510 35.1...
# 474      T32S R27E  2012  POLYGON ((-119.12837 35.09439, -119.12837 35.1...
# 475      T32S R28E  2012  POLYGON ((-119.02170 35.09292, -119.02170 35.1...
# 476      T32S R29E  2012  POLYGON ((-118.91470 35.09263, -118.91470 35.1...
# 477      T32S R30E  2012  POLYGON ((-118.80602 35.09275, -118.80602 35.1...
#
#      WELL_COUNT
# 0             1
# 1             1
# 2             4
# 3             3
# 4             1
# ..          ...
# 473           0
# 474           0
# 475           0
# 476           0
# 477           0
#
# [4780 rows x 4 columns]

# %%
shortage.map_df
# Out:
#     TOWNSHIP_RANGE  YEAR                                           geometry  \
# 0        T01N R07E  2021  POLYGON ((-121.25785 37.88341, -121.25785 37.9...
# 1        T01N R08E  2021  POLYGON ((-121.14913 37.88453, -121.14913 37.9...
# 2        T01S R08E  2021  POLYGON ((-121.03392 37.88617, -121.03392 37.7...
# 3        T01S R09E  2021  POLYGON ((-121.03686 37.88683, -120.92335 37.8...
# 4        T02N R06E  2021  POLYGON ((-121.37076 37.97036, -121.37076 38.0...
# ..             ...   ...                                                ...
# 473      T32S R26E  2012  POLYGON ((-119.23510 35.09371, -119.23510 35.1...
# 474      T32S R27E  2012  POLYGON ((-119.12837 35.09439, -119.12837 35.1...
# 475      T32S R28E  2012  POLYGON ((-119.02170 35.09292, -119.02170 35.1...
# 476      T32S R29E  2012  POLYGON ((-118.91470 35.09263, -118.91470 35.1...
# 477      T32S R30E  2012  POLYGON ((-118.80602 35.09275, -118.80602 35.1...
#
#      WELL_COUNT
# 0             1
# 1             1
# 2             4
# 3             3
# 4             1
# ..          ...
# 473           0
# 474           0
# 475           0
# 476           0
# 477           0
#
# [4780 rows x 4 columns]

# %% [markdown]
# ## Visualizing the Normalized Well Count

# %% [markdown]
# Compute the WELL_COUNT normalized by year

# %%
shortage.return_yearly_normalized_township_feature( 'WELL_COUNT',  "sum")
# Out:
# /work/milestone2_waterwells_deepnote/eda/../lib/shortage_v2.py:89: FutureWarning: Dropping invalid columns in DataFrameGroupBy.transform is deprecated. In a future version, a TypeError will be raised. Before calling .transform, select only columns which should be valid for the function.
#   self.map_df[f"YEARLY_{feature_name}"]= self.map_df.groupby('YEAR').transform(normalize_method)[feature_name]
#     TOWNSHIP_RANGE  YEAR                                           geometry  \
# 0        T01N R07E  2021  POLYGON ((-121.25785 37.88341, -121.25785 37.9...
# 1        T01N R08E  2021  POLYGON ((-121.14913 37.88453, -121.14913 37.9...
# 2        T01S R08E  2021  POLYGON ((-121.03392 37.88617, -121.03392 37.7...
# 3        T01S R09E  2021  POLYGON ((-121.03686 37.88683, -120.92335 37.8...
# 4        T02N R06E  2021  POLYGON ((-121.37076 37.97036, -121.37076 38.0...
# ..             ...   ...                                                ...
# 473      T32S R26E  2012  POLYGON ((-119.23510 35.09371, -119.23510 35.1...
# 474      T32S R27E  2012  POLYGON ((-119.12837 35.09439, -119.12837 35.1...
# 475      T32S R28E  2012  POLYGON ((-119.02170 35.09292, -119.02170 35.1...
# 476      T32S R29E  2012  POLYGON ((-118.91470 35.09263, -118.91470 35.1...
# 477      T32S R30E  2012  POLYGON ((-118.80602 35.09275, -118.80602 35.1...
#
#      WELL_COUNT  YEARLY_WELL_COUNT  WELL_COUNT_NORMALIZED
# 0             1                478               0.002092
# 1             1                478               0.002092
# 2             4                478               0.008368
# 3             3                478               0.006276
# 4             1                478               0.002092
# ..          ...                ...                    ...
# 473           0                  1               0.000000
# 474           0                  1               0.000000
# 475           0                  1               0.000000
# 476           0                  1               0.000000
# 477           0                  1               0.000000
#
# [4780 rows x 6 columns]

# %%
normalized_df = shortage.return_yearly_normalized_township_feature(feature_name="WELL_COUNT", normalize_method = "sum")
# Out:
# /work/milestone2_waterwells_deepnote/eda/../lib/shortage_v2.py:89: FutureWarning: Dropping invalid columns in DataFrameGroupBy.transform is deprecated. In a future version, a TypeError will be raised. Before calling .transform, select only columns which should be valid for the function.
#   self.map_df[f"YEARLY_{feature_name}"]= self.map_df.groupby('YEAR').transform(normalize_method)[feature_name]

# %% [markdown]
# ### Comparison per year

# %%
normalized_df.columns
# Out:
# Index(['TOWNSHIP_RANGE', 'YEAR', 'geometry', 'WELL_COUNT', 'YEARLY_WELL_COUNT',
#        'WELL_COUNT_NORMALIZED'],
#       dtype='object')

# %%
view_year_side_by_side(normalized_df, feature="WELL_COUNT_NORMALIZED", title="Well Counts")
# Out:
# alt.ConcatChart(...)

# %% [markdown]
# ### Map visualization for 2018

# %%
display_data_on_map(normalized_df, feature="WELL_COUNT_NORMALIZED", year=2018)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d0a37e32ac01416e8649e7d479ded7cf%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20table%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20margin%3A%20auto%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### Map visualization for 2021

# %%
display_data_on_map(normalized_df, feature="WELL_COUNT_NORMALIZED", year=2021)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_bec32cd4ba8a4c3fad845329b2b47bad%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.foliumtooltip%20table%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20margin%3A%20auto%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
shortage.prepare_output_from_map_df()

# %%
shortage.output_dataset_to_csv(output_filename="../assets/outputs/shortage_reports.csv")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b042e2da-6536-449d-95b8-d85fa08825de' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
