# %% [markdown]
# # San Joaquin Valley Water Shortages
# This notebook performs the ETL of the California water reservoir datasets in order to compute a percentage of capacity of the reservoirs per Township-Range and per year.
#
# Related links:
# * For the documentation about this dataset, its source, how to download, and the features of interest, please refer to our [Water Shortage Reports Dataset](doc/assets/shortage.md) documentation.

# %%
import sys
sys.path.append('..')

# %%
import numpy as np
import altair as alt

from lib.shortage import ShortageReportsDataset
from lib.viz import draw_missing_data_chart, view_trs_side_by_side, display_data_on_map

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
shortage = ShortageReportsDataset()
# Out:
# Loading local datasets. Please wait...
# Data not found locally.
# Downloading the water shortage reports dataset. Please wait...
# Downloads complete.
# Loading local datasets. Please wait...
# Loading of datasets complete.

# %%
print(shortage.map_df.shape)
shortage.map_df.sample(4)
# Out:
# (4792, 10)
#                        REPORT_DATE       COUNTY   LATITUDE   LONGITUDE  \
# 4469  SHORTAGE_REPORTED_2022-07-18       Fresno  36.716770 -119.540440
# 2358  SHORTAGE_REPORTED_2016-05-23       Tulare  36.098636 -119.107032
# 4788  SHORTAGE_REPORTED_2022-08-23  Santa Clara  37.128409 -121.705521
# 3887  SHORTAGE_REPORTED_2022-02-18       Fresno  36.790898 -119.897879
#
#                 STATUS           SHORTAGE_TYPE PRIMARY_USAGES  YEAR  MONTH  \
# 4469  Interim Solution  Dry well (groundwater)      Household  2022      7
# 2358  Interim Solution  Dry well (groundwater)      Household  2016      5
# 4788         Undefined  Dry well (groundwater)      Household  2022      8
# 3887         Undefined  Dry well (groundwater)      Household  2022      2
#
#                          geometry
# 4469  POINT (-119.54044 36.71677)
# 2358  POINT (-119.10703 36.09864)
# 4788  POINT (-121.70552 37.12841)
# 3887  POINT (-119.89788 36.79090)

# %% [markdown]
# Pre-process the shortage report data, geospatial location and combine them into the the geospatial map_df dataset and overlay the San Joaquin Valley boundaries to keep only the data in the San Joaquin Valley

# %%
shortage.preprocess_map_df(features_to_keep= ['REPORT_DATE', 'COUNTY', 'LATITUDE', 'LONGITUDE', 'STATUS', 'SHORTAGE_TYPE', 'PRIMARY_USAGES', "YEAR", "MONTH" , "geometry"])
shortage.keep_only_sjv_data()
shortage.map_df
# Out:
#                        REPORT_DATE       COUNTY   LATITUDE   LONGITUDE  \
# 0     SHORTAGE_REPORTED_2017-10-31         Kern  35.280117 -118.896376
# 1     SHORTAGE_REPORTED_2018-06-01         Kern  35.290510 -118.627383
# 2     SHORTAGE_REPORTED_2018-05-24         Kern  35.290852 -118.628775
# 3     SHORTAGE_REPORTED_2019-05-29         Kern  35.304669 -118.914434
# 4     SHORTAGE_REPORTED_2017-08-07         Kern  35.325274 -118.911520
# ...                            ...          ...        ...         ...
# 2571  SHORTAGE_REPORTED_2014-10-16  San Joaquin  37.827564 -120.937342
# 2572  SHORTAGE_REPORTED_2014-10-13  San Joaquin  37.828512 -120.952090
# 2573  SHORTAGE_REPORTED_2014-10-16  San Joaquin  37.841925 -120.978688
# 2574  SHORTAGE_REPORTED_2014-09-12  San Joaquin  37.842171 -120.976857
# 2575  SHORTAGE_REPORTED_2021-07-09       Amador  38.260793 -120.939198
#
#          STATUS                                  SHORTAGE_TYPE  \
# 0     Undefined                         Dry well (groundwater)
# 1     Undefined                         Dry well (groundwater)
# 2     Undefined   Owner of well will not fix problem with well
# 3     Undefined                  smell like oil, sand in water
# 4     Undefined                         Dry well (groundwater)
# ...         ...                                            ...
# 2571  Undefined                         Dry well (groundwater)
# 2572     Outage                         Dry well (groundwater)
# 2573  Undefined                         Dry well (groundwater)
# 2574     Outage                         Dry well (groundwater)
# 2575  Undefined                         Dry well (groundwater)
#
#                             PRIMARY_USAGES  YEAR  MONTH  \
# 0                                Household  2017     10
# 1                                Household  2018      6
# 2                                Household  2018      5
# 3                                Household  2019      5
# 4                                Household  2017      8
# ...                                    ...   ...    ...
# 2571                             Household  2014     10
# 2572  Combination of Household/Agriculture  2014     10
# 2573                             Household  2014     10
# 2574                             Household  2014      9
# 2575  Combination of Household/Agriculture  2021      7
#
#                          geometry
# 0     POINT (-118.89638 35.28012)
# 1     POINT (-118.62738 35.29051)
# 2     POINT (-118.62878 35.29085)
# 3     POINT (-118.91443 35.30467)
# 4     POINT (-118.91152 35.32527)
# ...                           ...
# 2571  POINT (-120.93734 37.82756)
# 2572  POINT (-120.95209 37.82851)
# 2573  POINT (-120.97869 37.84193)
# 2574  POINT (-120.97686 37.84217)
# 2575  POINT (-120.93920 38.26079)
#
# [2576 rows x 10 columns]

# %% [markdown]
# Look at missing data in the dataset

# %%
draw_missing_data_chart(shortage.map_df)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Map of the shortages in wells in the year 2015 in the San Joaquin Valley

# %%
display_data_on_map(shortage.map_df, feature="COUNTY", year=2015, color_scheme="tab10")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32bab728e0dd9ff6a02fe1e3f1c353ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div id=&#x27;maplegend COUNTY&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;COUNTY&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;Fresno&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff7f0e&#x27;&gt;&lt;/span&gt;Kings&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d62728&#x27;&gt;&lt;/span&gt;Madera&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8c564b&#x27;&gt;&lt;/span&gt;Merced&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e377c2&#x27;&gt;&lt;/span&gt;San Joaquin&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#bcbd22&#x27;&gt;&lt;/span&gt;Stanislaus&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#17becf&#x27;&gt;&lt;/span&gt;Tulare&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32bab728e0dd9ff6a02fe1e3f1c353ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_32bab728e0dd9ff6a02fe1e3f1c353ab = L.map(
#                 &quot;map_32bab728e0dd9ff6a02fe1e3f1c353ab&quot;,
#                 {
#                     center: [36.996058000000005, -120.2221335],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_32bab728e0dd9ff6a02fe1e3f1c353ab);
#
#
#
#
#
#             var tile_layer_cf969d358f73be4d7abab6853bb3fee6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_32bab728e0dd9ff6a02fe1e3f1c353ab);
#
#
#             map_32bab728e0dd9ff6a02fe1e3f1c353ab.fitBounds(
#                 [[35.791725, -121.511241], [38.200391, -118.933026]],
#                 {}
#             );
#
#
#         function geo_json_50d737ebd7988a935a805d03e0b0ca8f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;925&quot;: case &quot;945&quot;: case &quot;962&quot;: case &quot;968&quot;: case &quot;979&quot;: case &quot;980&quot;: case &quot;987&quot;: case &quot;1002&quot;: case &quot;1005&quot;: case &quot;1007&quot;: case &quot;1008&quot;: case &quot;1010&quot;: case &quot;1325&quot;: case &quot;1326&quot;: case &quot;1329&quot;: case &quot;1330&quot;: case &quot;1331&quot;: case &quot;1334&quot;: case &quot;1339&quot;: case &quot;1343&quot;:
#                     return {&quot;color&quot;: &quot;#ff7f0e&quot;, &quot;fillColor&quot;: &quot;#ff7f0e&quo

# %% [markdown]
# Next, for all Township-Ranges and every year:
#
# 1. Count the number of water shortage reports
# 2. Missing Township-Ranges had reports so we set their count of water shortage reports to 0

# %%
shortage.compute_features_by_township()
shortage.fill_townships_with_no_data(features_to_fill=["SHORTAGE_COUNT"], feature_value=0)
shortage.map_df
# Out:
#     TOWNSHIP_RANGE  YEAR                                           geometry  \
# 0        T01N R07E  2021  POLYGON ((-121.25785 37.88341, -121.25785 37.9...
# 1        T01N R08E  2021  POLYGON ((-121.14913 37.88453, -121.14913 37.9...
# 2        T01S R08E  2015  POLYGON ((-121.14772 37.88617, -121.03392 37.8...
# 3        T01S R08E  2021  POLYGON ((-121.03392 37.88617, -121.03392 37.7...
# 4        T01S R09E  2014  POLYGON ((-120.92335 37.88683, -120.92335 37.7...
# ..             ...   ...                                                ...
# 473      T32S R26E  2019  POLYGON ((-119.23510 35.09371, -119.23510 35.1...
# 474      T32S R27E  2019  POLYGON ((-119.12837 35.09439, -119.12837 35.1...
# 475      T32S R28E  2019  POLYGON ((-119.02170 35.09292, -119.02170 35.1...
# 476      T32S R29E  2019  POLYGON ((-118.91470 35.09263, -118.91470 35.1...
# 477      T32S R30E  2019  POLYGON ((-118.80602 35.09275, -118.80602 35.1...
#
#      SHORTAGE_COUNT
# 0                 1
# 1                 1
# 2                 2
# 3                 4
# 4                 4
# ..              ...
# 473               0
# 474               0
# 475               0
# 476               0
# 477               0
#
# [3824 rows x 4 columns]

# %% [markdown]
# ## Visualizing the Normalized Well Count
# ### Comparison per year
# Compute the WELL_COUNT normalized by year

# %%
normalized_df = shortage.return_yearly_normalized_township_feature(feature_name="SHORTAGE_COUNT", normalize_method = "minmax")
normalized_df
# Out:
#     TOWNSHIP_RANGE  YEAR                                           geometry  \
# 0        T01N R07E  2021  POLYGON ((-121.25785 37.88341, -121.25785 37.9...
# 1        T01N R08E  2021  POLYGON ((-121.14913 37.88453, -121.14913 37.9...
# 2        T01S R08E  2015  POLYGON ((-121.14772 37.88617, -121.03392 37.8...
# 3        T01S R08E  2021  POLYGON ((-121.03392 37.88617, -121.03392 37.7...
# 4        T01S R09E  2014  POLYGON ((-120.92335 37.88683, -120.92335 37.7...
# ..             ...   ...                                                ...
# 473      T32S R26E  2019  POLYGON ((-119.23510 35.09371, -119.23510 35.1...
# 474      T32S R27E  2019  POLYGON ((-119.12837 35.09439, -119.12837 35.1...
# 475      T32S R28E  2019  POLYGON ((-119.02170 35.09292, -119.02170 35.1...
# 476      T32S R29E  2019  POLYGON ((-118.91470 35.09263, -118.91470 35.1...
# 477      T32S R30E  2019  POLYGON ((-118.80602 35.09275, -118.80602 35.1...
#
#      SHORTAGE_COUNT  SHORTAGE_COUNT_NORMALIZED
# 0                 1                   0.031250
# 1                 1                   0.031250
# 2                 2                   0.013423
# 3                 4                   0.125000
# 4                 4                   0.027586
# ..              ...                        ...
# 473               0                   0.000000
# 474               0                   0.000000
# 475               0                   0.000000
# 476               0                   0.000000
# 477               0                   0.000000
#
# [3824 rows x 5 columns]

# %%
view_trs_side_by_side(normalized_df, feature="YEAR", value="SHORTAGE_COUNT_NORMALIZED", title="Water Shortage Reports Count")
# Out:
# alt.ConcatChart(...)

# %% [markdown]
# ### Map visualization for 2017

# %%
display_data_on_map(normalized_df, feature="SHORTAGE_COUNT_NORMALIZED", year=2017)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34d174d9a6c79602cd284d3073c62d0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34d174d9a6c79602cd284d3073c62d0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_34d174d9a6c79602cd284d3073c62d0d = L.map(
#                 &quot;map_34d174d9a6c79602cd284d3073c62d0d&quot;,
#                 {
#                     center: [36.70397957113992, -120.2168003995113],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_34d174d9a6c79602cd284d3073c62d0d);
#
#
#
#
#
#             var tile_layer_7805b3741a445800a782e486ca18ed5f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_34d174d9a6c79602cd284d3073c62d0d);
#
#
#             map_34d174d9a6c79602cd284d3073c62d0d.fitBounds(
#                 [[34.89762590740462, -121.86064515891064], [38.51033323487522, -118.57295564011196]],
#                 {}
#             );
#
#
#         function geo_json_837ef67f62bc335b6ce93495474bb1b9_styler(feature) {
#             switch(feature.properties.TOWNSHIP_RANGE) {
#                 case &quot;T03S R11E&quot;: case &quot;T05S R10E&quot;: case &quot;T05S R11E&quot;: case &quot;T06S R11E&quot;: case &quot;T06S R13E&quot;: case &quot;T07S R11E&quot;: case &quot;T10S R17E&quot;: case &quot;T12S R21E&quot;: case &quot;T13S R22E&quot;: case &quot;T14S R20E&quot;: case &quot;T14S R21E&quot;: case &quot;T15S R21E&quot;: case &quot;T16S R21E&quot;: case &quot;T16S R22E&quot;: case &quot;T17S R21E&quot;: case &quot;T17S R24E&quot;: case &quot;T17S R25E&quot;: case &quot;T18S R21E&quot;: case &quot;T18S R22E&quot;: case &quot;T18S R24E&quot;: case &quot;T18S R25E&quot;: case &quot;T19S R20E&quot;: case &quot;T19S R22E&quot;: case &quot;T19S R25E&quot;: case &quot;T20S R24E&quot;: case &quot;T20S R25E&quot;: case &quot;T21S R28E&quot;: case &quot;T22S R24E&quot;: case &quot;T22S R25E&quot;: case &quot;T27S R25E&quot;: case &quot;T27S R28E&quot;: case &quot;T29S R25E&quot;: case &quot;T29S R26E&quot;: case &quot;T30S R28E&quot;:
#                     return {&quot;color&quot;: &quot;#6b89bb&quot;, &quot;fillColor&quot;: &quot;#6b89bb&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;T07S R13E&quot;: case &quot;T11S R17E&quot;: case &quot;T11S R18E&quot;: case &quot;T20S R20E&quot;: case &quot;T23S R25E&quot;: case &quot;T28S R25E&quot;: case &quot;T30S R29E&quot;:
#                     return {&quot;color&quot;: &quot;#7784b6&quot;, &quot;fillColor&quot;: &quot;#7784b6&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;T07S R14E&quot;: case &quot;T11S R19E&quot;: case &quot;T15S R20E&quot;: case &quot;T16S R25E&quot;: case &quot;T21S R27E&quot;:
#                     return {&quot;color&quot;: &quot;#827fb0&quot;, &quot;fillColor&quot;: &quot;#827fb0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;T10S R18E&quot;:
#                     return {&quot;color&quot;: &quot;#e37113&quot;, &quot;fillColor&quot;: &quot;#e37113&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;T20S R26E&quot;:
#                     return {&quot;color&quot;: &quot;#cd6e4d&quot;, &quot;fillColor&quot;: &quot;#cd6e4d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#608ec1&quot;, &quot;fillColor&quot;: &quot;#608ec1&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_837ef67f62bc335b6ce93495474bb1b9_highlighter(feature) {
#             switch(feature.properties.TOWNSHIP_RANGE) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_837ef67f62bc335b6ce93495474bb1b9_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2,

# %% [markdown]
# ### Map visualization for 2021

# %%
display_data_on_map(normalized_df, feature="SHORTAGE_COUNT_NORMALIZED", year=2021)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6a2cb0a690e51db2464ca477e681fe8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6a2cb0a690e51db2464ca477e681fe8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c6a2cb0a690e51db2464ca477e681fe8 = L.map(
#                 &quot;map_c6a2cb0a690e51db2464ca477e681fe8&quot;,
#                 {
#                     center: [36.70397957113992, -120.2168003995113],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c6a2cb0a690e51db2464ca477e681fe8);
#
#
#
#
#
#             var tile_layer_2bd324341f4a2f1b9a12ef7b1f212aa4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c