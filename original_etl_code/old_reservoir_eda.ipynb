# %% [markdown]
# # Exploring precipitation reports over the years in San Joaquin townships

# %%
import sys
sys.path.append('..')

# %%
import json
import pprint
import folium
import numpy as np
import pandas as pd
import altair as alt

import geopandas as gpd
from shapely import wkt

import branca.colormap as cm
import matplotlib.pyplot as plt
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
import  geodataframe_aggregate_functions  as gaf
from geodataframe_visualization_class import NormalizedDataSliderVisualization

# %%
gaf.merge_data_plss( "../assets/outputs/precipitation_stations.csv", "../assets/outputs/precipitation_stations_plss.csv")
# Out:
#      STATION_ID         STATION NAME   OCT   NOV   DEC   JAN   FEB   MAR  \
# 55          BFK  BAKERSFIELD AIRPORT  0.02  0.10  0.65  0.83  0.60  0.83
# 56          BFK  BAKERSFIELD AIRPORT  0.03  0.94  0.10  0.12  0.32  0.36
# 57          BFK  BAKERSFIELD AIRPORT  0.64  0.01  2.02  0.69  0.90  0.27
# 58          BFK  BAKERSFIELD AIRPORT  0.14  0.61  0.58  1.95  0.25  0.45
# 59          BFK  BAKERSFIELD AIRPORT  0.24  0.38  2.41  2.76  1.46  0.16
# ...         ...                  ...   ...   ...   ...   ...   ...   ...
# 1583        WSC                WASCO  0.00  0.52  0.00  1.17  0.33  1.57
# 1584        WSC                WASCO  0.00  0.73  0.33  1.43  1.86  1.96
# 1585        WSC                WASCO  0.00  2.48  1.77  0.00  0.00  1.85
# 1586        WSC                WASCO  0.00  0.20  0.42  1.33  0.21  0.69
# 1587        WSC                WASCO  1.02  0.40  2.88  0.00   NaN   NaN
#
#        APR   MAY  ...                     geometry  index_right  \
# ...

# %%
precipitation_gdf =  get_yearly_data( input_file =  "../assets/outputs/precipitation_stations_plss.csv", 
                        time_aggregate_column = 'YEAR',
                        year_avg_column_name =  'YEARLY_PRECIPITATION_MEAN',
                        col_to_aggr = 'AVERAGE_YEARLY_PRECIPITATION',
                        agg_func =  'mean',
                        time_value ='2013',
                        drop_nulls=True)
   
township_aggregate_gdf = gaf.get_normalized_data (gdf =precipitation_gdf,
                            geometry_col_list = [ 'TownshipRange', 'COUNTY'],
                            time_aggregate_column = 'YEAR',
                            year_agg_column_name = 'YEARLY_PRECIPITATION_MEAN',
                            col_to_agg = 'AVERAGE_YEARLY_PRECIPITATION',
                            agg_func =  'mean')

# %%
alt.Chart(df).mark_bar().encode( x="YEAR:N",y='YEARLY_PRECIPITATION_MEAN:Q', color='STATION NAME:N')
# Out:
# alt.Chart(...)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b042e2da-6536-449d-95b8-d85fa08825de' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
