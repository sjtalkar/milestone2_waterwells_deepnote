# %%
import sys
sys.path.append('..')



import numpy as np
import pandas as pd
import altair as alt
from lib.viz import sjv_color_range_17, sjv_color_range_9, get_model_errors, chart_error_distribution, chart_error_by_township, chart_error_by_depth
# Out:
# /root/venv/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# Insights into the model

# %% [markdown]
# - Feature importance and feature ablation through SHAP can be seen here in the section called Explainabilty through SHAP.

# %% [markdown]
# - Failure/Error analysis is conducted below

# %%
test_model_errors_df, error_df = get_model_errors()

# %%
test_model_errors_df
# Out:
#                            Mean Absolute Error  Mean Squared Error     R^2  \
# SVR                                    29.1754           2046.5795  0.8779
# GradientBoostingRegressor              32.5584           2435.5293  0.8547
# RandomForestRegressor                  30.9034           2567.8967  0.8468
# CatBoostRegressor                      31.6958           2793.4808  0.8334
# XGBRegressor                           31.9311           2896.8935  0.8272
# KNeighborsRegressor                    54.9149           5785.1928  0.6550
#
#                               RMSE
# SVR                        45.2391
# GradientBoostingRegressor  49.3511
# RandomForestRegressor      50.6744
# CatBoostRegressor          52.8534
# XGBRegressor               53.8228
# KNeighborsRegressor        76.0605

# %% [markdown]
# ### Analyzing the pattern of errors made in the regressors RandomForest and SVR

# %%
chart_error_distribution(error_df)
# Out:
# alt.FacetChart(...)

# %%
model_name_list = [
    "CatBoostRegressor_absolute_error",
    "SVR_absolute_error",
    "RandomForestRegressor_absolute_error",
]

chart_error_by_depth(error_df, model_name_list)
# Out:
# alt.FacetChart(...)

# %% [markdown]
# Also check the top township ranges for which error is high

# %%
chart_error_by_township(error_df, model_name_list)
# Out:
# alt.Chart(...)

# %% [markdown]
# The townships where the highest absolute errors made are shown above.
# - T15S R10E
# - T10S R21E
# - T27S R27E
# - T20S R18E
# - T22S R17E
# - T22S R28E
# - T22S R16E
# - T27S R26E

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b042e2da-6536-449d-95b8-d85fa08825de' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
